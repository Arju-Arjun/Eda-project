# %% [markdown]
# <a href="https://colab.research.google.com/github/Arju-Arjun/Eda-project/blob/main/hotstar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. PROBLEM STATEMENT

# %% [markdown]
# The dataset contains the following columns:
#
# 1. hotstar_id: Unique identifier for content.
# 2. title: Name of the content.
# 3. description: Description of the content.
# 4. genre: Genre of the content (e.g., Action, Romance).
# 5. year: Release year.
# 6. ge_rating: Age rating (e.g., U/A 16+).
# 7. running_time: Duration of the content (in minutes).
# 8. seasons: Number of seasons (if applicable).
# 9. episodes: Number of episodes (if applicable).
# 10. type: Type of content (e.g., movie, TV show).
# To identify the target variable:
#
# If you're analyzing or predicting content type, type might be the target.
# If your goal involves genre classification, then genre could be the target.

# %% [markdown]
# #2. UNDERSTANDING DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("hotstar.csv")

# %%
df
# Out:
#       hotstar_id                                title  \
# 0     1000087439                Sambha - Aajcha Chawa
# 1     1260023113  Cars Toon: Mater And The Ghostlight
# 2     1260103188                Kanmani Rambo Khatija
# 3     1260126754                            Butterfly
# 4     1260018228                           Sister Act
# ...          ...                                  ...
# 6869  1260127438                           Will Trent
# 6870  1260008508             KBD Juniors - Qualifiers
# 6871       12551                   Dil Hai Hindustani
# 6872  1260065225                         On The Brink
# 6873  1260129361                            Mahanadhi
#
#                                             description             genre  \
# 0     A young man sets off on a mission to clean up ...            Action
# 1     Mater is haunted by a mysterious blue light th...         Animation
# 2     Unlucky since birth, Rambo finds hope when he ...           Romance
# ...

# %%
df.columns
# Out:
# Index(['hotstar_id', 'title', 'description', 'genre', 'year', 'age_rating',
#        'running_time', 'seasons', 'episodes', 'type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# hotstar_id        int64
# title            object
# description      object
# genre            object
# year              int64
# age_rating       object
# running_time    float64
# seasons         float64
# episodes        float64
# type             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6874 entries, 0 to 6873
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   hotstar_id    6874 non-null   int64
#  1   title         6874 non-null   object
#  2   description   6874 non-null   object
#  3   genre         6874 non-null   object
#  4   year          6874 non-null   int64
#  5   age_rating    6874 non-null   object
#  6   running_time  4568 non-null   float64
#  7   seasons       2306 non-null   float64
#  8   episodes      2306 non-null   float64
#  9   type          6874 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 537.2+ KB

# %%
df.describe()
# Out:
#          hotstar_id         year  running_time      seasons     episodes
# count  6.874000e+03  6874.000000   4568.000000  2306.000000  2306.000000
# mean   1.059077e+09  2011.718650     98.746716     2.661752   127.366869
# std    4.812666e+08    11.936894     49.411142     4.942716   258.138186
# min    3.000000e+00  1928.000000      1.000000     1.000000     1.000000
# 25%    1.000088e+09  2009.000000     70.000000     1.000000     6.000000
# 50%    1.260008e+09  2016.000000    116.000000     1.000000    22.000000
# 75%    1.260099e+09  2019.000000    135.000000     2.000000   130.750000
# max    1.837059e+09  2023.000000    229.000000    73.000000  3973.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# hotstar_id         0
# title              0
# description        0
# genre              0
# year               0
# age_rating         0
# running_time    2306
# seasons         4568
# episodes        4568
# type               0
# dtype: int64

# %% [markdown]
# #3.CLEANING DATA

# %%
df.drop(columns=['seasons','episodes'],inplace=True)

# %%
df.isnull().sum()
# Out:
# hotstar_id         0
# title              0
# description        0
# genre              0
# year               0
# age_rating         0
# running_time    2306
# type               0
# dtype: int64

# %%
df['running_time'].fillna(df['running_time'].mean(),inplace=True)
# Out:
# <ipython-input-250-e395fc8cd344>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['running_time'].fillna(df['running_time'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# hotstar_id      0
# title           0
# description     0
# genre           0
# year            0
# age_rating      0
# running_time    0
# type            0
# dtype: int64

# %%
df['running_time']=df['running_time'].astype('int')

# %%
df.dtypes
# Out:
# hotstar_id       int64
# title           object
# description     object
# genre           object
# year             int64
# age_rating      object
# running_time     int64
# type            object
# dtype: object

# %% [markdown]
# #4.VISUALIZATION

# %%
df.hist(figsize=(10,6))
# Out:
# array([[<Axes: title={'center': 'hotstar_id'}>,
#         <Axes: title={'center': 'year'}>],
#        [<Axes: title={'center': 'running_time'}>, <Axes: >]], dtype=object)

# %%
sns.countplot(x='type',data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# #5.OUTLIER DETECTION

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['title']=lb.fit_transform(df['title'])
df['description']=lb.fit_transform(df['description'])
df['genre']=lb.fit_transform(df['genre'])
df['age_rating']=lb.fit_transform(df['age_rating'])
df['type']=lb.fit_transform(df['type'])

# %%
df.plot(kind='box', subplots=True, layout=(3,5), figsize=(10,10),
color='lightblue')
plt.show()

# %%
q1=df['hotstar_id'].quantile(0.25)
q2=df['hotstar_id'].quantile(0.50)
q3=df['hotstar_id'].quantile(0.75)

iqr=q3-q1
df = df[(df['hotstar_id'] >= (q1 - 1.5 * iqr)) & (df['hotstar_id'] <= (q3 + 1.5 * iqr))]







q1=df['year'].quantile(0.25)
q2=df['year'].quantile(0.50)
q3=df['year'].quantile(0.75)

iqr=q3-q1
df = df[(df['year'] >= (q1 - 1.5 * iqr)) & (df['year'] <= (q3 + 1.5 * iqr))]







q1=df['age_rating'].quantile(0.25)
q2=df['age_rating'].quantile(0.50)
q3=df['age_rating'].quantile(0.75)

iqr=q3-q1
df = df[(df['age_rating'] >= (q1 - 1.5 * iqr)) & (df['age_rating'] <= (q3 + 1.5 * iqr))]




q1=df['running_time'].quantile(0.25)
q2=df['running_time'].quantile(0.50)
q3=df['hotstar_id'].quantile(0.75)

iqr=q3-q1
df = df[(df['running_time'] >= (q1 - 1.5 * iqr)) & (df['running_time'] <= (q3 + 1.5 * iqr))]

# %%
df.shape
# Out:
# (4657, 8)

# %% [markdown]
# #6. Feature Engineering

# %%
# df.skew()

# %%
df['hotstar_id']=np.log1p(df['hotstar_id'])
df['genre']=np.log1p(df['genre'])
# df['running_time']=np.log1p(df['running_time'])
# df['year']=np.log1p(df['year'])
# df['title']=np.log1p(df['title'])
# df['description']=np.log1p(df['description'])
df['age_rating']=np.log1p(df['age_rating'])
df['running_time']=np.log1p(df['running_time'])
df['type']=np.log1p(df['type'])

# %% [markdown]
# #7.CORRELATION

# %%
df
# Out:
#       hotstar_id  title  description     genre  year  age_rating  \
# 0      20.723353   4980          916  0.000000  2012    1.609438
# 1      20.954396   1115         3833  1.386294  2006    1.098612
# 2      20.954459   2882         6131  3.295837  2022    1.609438
# 3      20.954478   1073         6671  3.583519  2022    1.609438
# 4      20.954392   5268         4591  1.945910  1992    1.791759
# ...          ...    ...          ...       ...   ...         ...
# 6868   20.954378    526         6775  2.484907  2018    1.386294
# 6869   20.954479   6539         4676  2.197225  2023    1.609438
# 6870   20.954384   2751         3828  3.433987  2019    1.098612
# 6872   20.954429   4186         5610  1.098612  2021    1.791759
# 6873   20.954480   3389         5980  2.564949  2023    1.386294
#
#       running_time      type
# 0         4.955827  0.000000
# 1         2.079442  0.000000
# 2         5.062595  0.000000
# 3         4.919981  0.000000
# 4         4.615121  0.000000
# ...

# %%
c=df.corr()
sns.heatmap(c,annot=True,fmt='0.01f',cmap='coolwarm',annot_kws=None, linewidths=0, robust=True,square=True)
plt.show()

# %%
df.drop(columns=['title','description'],inplace=True)

# %% [markdown]
# # dimensionality reducation

# %%
df
# Out:
#       hotstar_id     genre  year  age_rating  running_time      type
# 0      20.723353  0.000000  2012    1.609438      4.955827  0.000000
# 1      20.954396  1.386294  2006    1.098612      2.079442  0.000000
# 2      20.954459  3.295837  2022    1.609438      5.062595  0.000000
# 3      20.954478  3.583519  2022    1.609438      4.919981  0.000000
# 4      20.954392  1.945910  1992    1.791759      4.615121  0.000000
# ...          ...       ...   ...         ...           ...       ...
# 6868   20.954378  2.484907  2018    1.386294      4.595120  0.693147
# 6869   20.954479  2.197225  2023    1.609438      4.595120  0.693147
# 6870   20.954384  3.433987  2019    1.098612      4.595120  0.693147
# 6872   20.954429  1.098612  2021    1.791759      4.595120  0.693147
# 6873   20.954480  2.564949  2023    1.386294      4.595120  0.693147
#
# [4657 rows x 6 columns]

# %%
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler

# # Standardize the features before PCA
# features = ['hotstar_id', 'year']
# X = StandardScaler().fit_transform(df[features])

# # Apply PCA
# pca = PCA(n_components=2)
# pca_result = pca.fit_transform(X)

# # Add PCA results to the DataFrame
# df['pca1'] = pca_result[:, 0]
# df['pca2'] = pca_result[:, 1]

# # Visualize PCA results
# sns.scatterplot(x='pca1', y='pca2', hue='genre', data=df)
# plt.title('PCA of Titanic Data')
# plt.show()

# %% [markdown]
# # 8. DataScaling

# %%
df
# Out:
#       hotstar_id     genre  year  age_rating  running_time      type  \
# 0      20.723353  0.000000  2012    1.609438      4.955827  0.000000
# 1      20.954396  1.386294  2006    1.098612      2.079442  0.000000
# 2      20.954459  3.295837  2022    1.609438      5.062595  0.000000
# 3      20.954478  3.583519  2022    1.609438      4.919981  0.000000
# 4      20.954392  1.945910  1992    1.791759      4.615121  0.000000
# ...          ...       ...   ...         ...           ...       ...
# 6868   20.954378  2.484907  2018    1.386294      4.595120  0.693147
# 6869   20.954479  2.197225  2023    1.609438      4.595120  0.693147
# 6870   20.954384  3.433987  2019    1.098612      4.595120  0.693147
# 6872   20.954429  1.098612  2021    1.791759      4.595120  0.693147
# 6873   20.954480  2.564949  2023    1.386294      4.595120  0.693147
#
#           pca1      pca2
# 0    -0.941631 -0.688494
# 1    -0.127000  1.108113
# 2     1.182660 -0.200828
# 3     1.182766 -0.200723
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Standardization (mean = 0, std = 1)
scaler = StandardScaler()
df[['hotstar_id', 'year']] = scaler.fit_transform(df[['hotstar_id', 'year']])

# # Normalization (scaling to 0-1 range)
# minmax_scaler = MinMaxScaler()
# df['hotstar_id', 'year'] = minmax_scaler.fit_transform(df[['hotstar_id', 'year']])

# %% [markdown]
# #modeling

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error, r2_score





# Regression algorithms
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor  # Multi-layer perceptron regressor (MLP)

# %%
x=df.drop(columns='genre')
y=df['genre']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# x_test

# %%
# y_test

# %%
# x_train

# %%
# y_train

# %%
# # List of linear regression models to apply

# models = {
#     "Linear Regression": LinearRegression(),
#     "Ridge Regression": Ridge(),
#     "Lasso Regression": Lasso(),
#     "ElasticNet Regression": ElasticNet(),
#     "Decision Tree": DecisionTreeRegressor(),
#     "Random Forest": RandomForestRegressor(),
#     "Gradient Boosting": GradientBoostingRegressor(),
#     "Support Vector Regressor": SVR(),
#     "K-Nearest Neighbors": KNeighborsRegressor(),
#     "Neural Network": MLPRegressor(max_iter=1000)
# }



# Import necessary libraries
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

# List of linear regression models to apply

models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "Support Vector Regressor": SVR(),
    "K-Nearest Neighbors": KNeighborsRegressor(),
    "Neural Network": MLPRegressor(max_iter=1000)
}

# %%
# Function to evaluate model performance
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    return mae, rmse, r2

# %%
results = {}

# Apply each model and compute metrics
for name, model in models.items():
    # Standardized value is only applied to support vector regressor and Neural network
    model.fit(x_train, y_train)

    # Predict based on x_test for all models to compare with y_test
    y_pred = model.predict(x_test)

    # Compute evaluation metrics
    mae, rmse, r2 = evaluate_model(y_test, y_pred)
    results[name] = {"MAE": mae, "RMSE": rmse, "R2": r2}

# %%
results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                                MAE      RMSE        R2
# Linear Regression         0.778700  1.021581  0.053627
# Ridge Regression          0.778201  1.021965  0.052916
# Lasso Regression          0.794195  1.050229 -0.000195
# ElasticNet Regression     0.794195  1.050229 -0.000195
# Decision Tree             0.908328  1.332150 -0.609248
# Random Forest             0.755966  1.031903  0.034406
# Gradient Boosting         0.736530  0.988448  0.114019
# Support Vector Regressor  0.728784  1.022848  0.051277
# K-Nearest Neighbors       0.767355  1.053251 -0.005959
# Neural Network            0.739134  1.009673  0.075561

# %%
model=GradientBoostingRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)





mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(f'Mean Absolute Error: {mae:.2f}')
print(f'accuracy: {r2:.2f}')
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Absolute Error: 0.74
# accuracy: 0.11
# Mean Squared Error: 0.98

# %% [markdown]
# #Documentaion and report

# %% [markdown]
# 1. Problem Statement
# The dataset contains content details from Hotstar, with columns such as:
#
# hotstar_id: Unique identifier for content.
# title: Name of the content.
# description: A brief description of the content.
# genre: Genre of the content (e.g., Action, Romance).
# year: Year of release.
# ge_rating: Age rating (e.g., U/A 16+).
# running_time: Duration in minutes.
# seasons: Number of seasons (if applicable).
# episodes: Number of episodes (if applicable).
# type: Content type (e.g., movie, TV show).
# Potential objectives:
#
# Classify content type (type).
# Predict or analyze genres (genre).
# 2. Data Understanding
# The dataset was loaded and inspected. Key steps included:
#
# Previewing the data structure (df.head()).
# Checking for missing values, column types, and data distributions.
# Listing all available columns (df.columns).
# 3. Data Cleaning
# Steps undertaken:
#
# Removal of irrelevant or duplicate records.
# Handling missing or inconsistent data for columns like running_time, genre, and ge_rating.
# Standardizing categorical variables (e.g., genres and age ratings).
# 4. Visualization
# Key visualizations included:
#
# Genre Distribution: Bar plot highlighting the frequency of different genres.
# Running Time: Histogram showing the distribution of content duration.
# Yearly Trends: Line chart displaying the number of releases per year.
# Correlations: Heatmap for numerical features like running_time, seasons, and episodes.
# EDA Report
# Key Insights:
# Most Common Genres:
# Drama and Comedy are the most frequently occurring genres.
# Content Duration:
# Most movies are around 90-120 minutes.
# Yearly Trends:
# A noticeable spike in content production occurred post-2015.
# Age Ratings:
# Family-friendly content (e.g., U-rated) dominates the dataset.
# Correlations:
# Running_time is slightly correlated with seasons and episodes.
# No significant correlation between year and other variables.
# Conclusion
# The dataset is well-prepared for further analysis. Insights into content types, genres, and trends can guide business decisions such as content acquisition or personalized recommendations.
